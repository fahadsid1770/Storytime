# %%
! pip install datasets
! pip install tiktoken 
! pip install -U datasets

# %%
# Example for CUDA 12.6 for GPU support
# ! pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu126
# Out:
# ^C
# Looking in indexes: https://download.pytorch.org/whl/cu126
# Requirement already satisfied: torch in e:\ai-testing\aesop-slm\venv\lib\site-packages (2.8.0)
# Collecting torchvision
#   Downloading https://download.pytorch.org/whl/cu126/torchvision-0.23.0%2Bcu126-cp312-cp312-win_amd64.whl.metadata (6.3 kB)
# Collecting torchaudio
#   Downloading https://download.pytorch.org/whl/cu126/torchaudio-2.8.0%2Bcu126-cp312-cp312-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: filelock in e:\ai-testing\aesop-slm\venv\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in e:\ai-testing\aesop-slm\venv\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in e:\ai-testing\aesop-slm\venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in e:\ai-testing\aesop-slm\venv\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in e:\ai-testing\aesop-slm\venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in e:\ai-testing\aesop-slm\venv\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: setuptools in e:\ai-testing\aesop-slm\venv\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: numpy in e:\ai-testing\aesop-slm\venv\lib\site-packages (from torchvision) (2.3.3)
# Collecting torch
#   Downloading https://download.pytorch.org/whl/cu126/torch-2.8.0%2Bcu126-cp312-cp312-win_amd64.whl.metadata (29 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in e:\ai-testing\aesop-slm\venv\lib\site-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in e:\ai-testing\aesop-slm\venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in e:\ai-testing\aesop-slm\venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Downloading https://download.pytorch.org/whl/cu126/torchvision-0.23.0%2Bcu126-cp312-cp312-win_amd64.whl (6.2 MB)
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.2 MB ? eta -:--:--
#    ---------- ----------------------------- 1.6/6.2 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 3.7/6.2 MB 7.3 MB/s eta 0:00:01
#    ---------------------------- ----------- 4.5/6.2 MB 5.5 MB/s eta 0:00:01
#    -------------------------------------- - 6.0/6.2 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 5.5 MB/s  0:00:01
# Downloading https://download.pytorch.org/whl/cu126/torch-2.8.0%2Bcu126-cp312-cp312-win_amd64.whl (2915.4 MB)
#    ---------------------------------------- 0.0/2.9 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.9 GB 21.1 MB/s eta 0:02:18
#    ---------------------------------------- 0.0/2.9 GB 5.3 MB/s eta 0:09:07
#    ---------------------------------------- 0.0/2.9 GB 5.2 MB/s eta 0:09:16
#    ---------------------------------------- 0.0/2.9 GB 5.5 MB/s eta 0:08:53
#    ---------------------------------------- 0.0/2.9 GB 6.8 MB/s eta 0:07:10
#    ---------------------------------------- 0.0/2.9 GB 5.7 MB/s eta 0:08:34
#    ---------------------------------------- 0.0/2.9 GB 6.0 MB/s eta 0:08:08
#    ---------------------------------------- 0.0/2.9 GB 6.1 MB/s eta 0:07:53
#    ---------------------------------------- 0.0/2.9 GB 6.4 MB/s eta 0:07:36
#    ---------------------------------------- 0.0/2.9 GB 6.2 MB/s eta 0:07:47
#    ---------------------------------------- 0.0/2.9 GB 5.9 MB/s eta 0:08:11
#    ---------------------------------------- 0.0/2.9 GB 5.8 MB/s eta 0:08:16
#    ---------------------------------------- 0.0/2.9 GB 5.8 MB/s eta 0:08:18
#    ---------------------------------------- 0.0/2.9 GB 6.1 MB/s eta 0:07:56
#    ---------------------------------------- 0.0/2.9 GB 6.1 MB/s eta 0:07:52
#    ---------------------------------------- 0.0/2.9 GB 6.1 MB/s eta 0:07:55
#    ---------------------------------------- 0.0/2.9 GB 6.2 MB/s eta 0:07:49
#    ---------------------------------------- 0.0/2.9 GB 6.1 MB/s eta 0:07:56
#    ---------------------------------------- 0.0/2.9 GB 6.2 MB/s eta 0:07:50
#    ---------------------------------------- 0.0/2.9 GB 6.0 MB/s eta 0:08:00
#    ---------------------------------------- 0.0/2.9 GB 5.9 MB/s eta 0:08:10
#    ---------------------------------------- 0.0/2.9 GB 5.9 MB/s eta 0:08:06
#    ---------------------------------------- 0.0/2.9 GB 6.1 MB/s eta 0:07:57
#    ---------------------------------------- 0.0/2.9 GB 6.0 MB/s eta 0:08:02
#    ---------------------------------------- 0.0/2.9 GB 6.0 MB/s eta 0:07:59
#    ---------------------------------------- 0.0/2.9 GB 6.0 MB/s eta 0:07:59
#    ---------------------------------------- 0.0/2.9 GB 5.7 MB/s eta 0:08:30
#    ---------------------------------------- 0.0/2.9 GB 5.7 MB/s eta 0:08:26
#    ---------------------------------------- 0.0/2.9 GB 5.6 MB/s eta 0:08:35
#    ---------------------------------------- 0.0/2.9 GB 5.7 MB/s eta 0:08:26
#    ---------------------------------------- 0.0/2.9 GB 5.7 MB/s eta 0:08:24
#     --------------------------------------- 0.0/2.9 GB 5.6 MB/s eta 0:08:30
#     --------------------------------------- 0.0/2.9 GB 5.7 MB/s eta 0:08:27
#     --------------------------------------- 0.0/2.9 GB 5.7 MB/s eta 0:08:24
#     --------------------------------------- 0.0/2.9 GB 5.6 MB/s eta 0:08:32
#     --------------------------------------- 0.0/2.9 GB 5.6 MB/s eta 0:08:30
#     --------------------------------------- 0.0/2.9 GB 5.7 MB/s eta 0:08:26
#     --------------------------------------- 0.0/2.9 GB 5.8 MB/s eta 0:08:13
#     --------------------------------------- 0.0/2.9 GB 5.9 MB/s eta 0:08:10
#     --------------------------------------- 0.0/2.9 GB 5.9 MB/s eta 0:08:03
#     --------------------------------------- 0.0/2.9 GB 5.9 MB/s eta 0:08:03
#     --------------------------------------- 0.1/2.9 GB 5.9 MB/s eta 0:08:02
#     --------------------------------------- 0.1/2.9 GB 5.8 MB/s eta 0:08:17
#     --------------------------------------- 0.1/2.9 GB 5.8 MB/s eta 0:08:18
#     --------------------------------------- 0.1/2.9 GB 5.7 MB/s eta 0:08:26
#     --------------------------------------- 0.1/2.9 GB 5.7 MB/s eta 0:08:26
#     --------------------------------------- 0.1/2.9 GB 5.5 MB/s eta 0:08:41
#     --------------------------------------- 0.1/2.9 GB 5.5 MB/s eta 0:08:45
#     --------------------------------------- 0.1/2.9 GB 5.4 MB/s eta 0:08:47
#     --------------------------------------- 0.1/2.9 GB 5.3 MB/s eta 0:08:55
#     --------------------------------------- 0.1/2.9 GB 5.3 MB/s eta 0:09:01
#     --------------------------------------- 0.1/2.9 GB 5.2 MB/s eta 0:09:11
#     --------------------------------------- 0.1/2.9 GB 5.1 MB/s eta 0:09:17
#     --------------------------------------- 0.1/2.9 GB 5.1 MB/s eta 0:09:18
#     --------------------------------------- 0.1/2.9 GB 5.0 MB/s eta 0:09:30
#     --------------------------------------- 0.1/2.9 GB 5.0 MB/s eta 0:09:38
#     --------------------------------------- 0.1/2.9 GB 4.9 MB/s eta 0:09:42
#     --------------------------------------- 0.1/2.9 GB 4.9 MB/s eta 0:09:47
#     --------------------------------------- 0.1/2.9 GB 4.8 MB/s eta 0:09:54
#     --------------------------------------- 0.1/2.9 GB 4.8 MB/s eta 0:09:57
#     --------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:10:03
#     --------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:10:06
#     --------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:10:12
#     --------------------------------------- 0.1/2.9 GB 4.6 MB/s eta 0:10:17
#     --------------------------------------- 0.1/2.9 GB 4.6 MB/s eta 0:10:23
#     --------------------------------------- 0.1/2.9 GB 4.6 MB/s eta 0:10:23
#     --------------------------------------- 0.1/2.9 GB 4.5 MB/s eta 0:10:33
#     --------------------------------------- 0.1/2.9 GB 4.5 MB/s eta 0:10:36
#     --------------------------------------- 0.1/2.9 GB 4.5 MB/s eta 0:10:38
#     --------------------------------------- 0.1/2.9 GB 4.4 MB/s eta 0:10:45
#     --------------------------------------- 0.1/2.9 GB 4.4 MB/s eta 0:10:47
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:10:57
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:00
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:04
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:06
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:06
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:07
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:08
#     --------------------------------------- 0.1/2.9 GB 4.2 MB/s eta 0:11:13
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:09
#     --------------------------------------- 0.1/2.9 GB 4.2 MB/s eta 0:11:10
#     --------------------------------------- 0.1/2.9 GB 4.2 MB/s eta 0:11:10
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:09
#     --------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:09
#    - -------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:07
#    - -------------------------------------- 0.1/2.9 GB 4.2 MB/s eta 0:11:11
#    - -------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:08
#    - -------------------------------------- 0.1/2.9 GB 4.2 MB/s eta 0:11:12
#    - -------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:11:02
#    - -------------------------------------- 0.1/2.9 GB 4.3 MB/s eta 0:10:54
#    - -------------------------------------- 0.1/2.9 GB 4.4 MB/s eta 0:10:38
#    - -------------------------------------- 0.1/2.9 GB 4.4 MB/s eta 0:10:39
#    - -------------------------------------- 0.1/2.9 GB 4.5 MB/s eta 0:10:33
#    - -------------------------------------- 0.1/2.9 GB 4.6 MB/s eta 0:10:18
#    - -------------------------------------- 0.1/2.9 GB 4.6 MB/s eta 0:10:21
#    - -------------------------------------- 0.1/2.9 GB 4.6 MB/s eta 0:10:20
#    - -------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:10:06
#    - -------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:09:58
#    - -------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:10:02
#    - -------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:10:02
#    - -------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:10:05
#    - -------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:10:05
#    - -------------------------------------- 0.1/2.9 GB 4.7 MB/s eta 0:10
MB/s eta 0:05:42
#    ---------- ----------------------------- 0.7/2.9 GB 6.3 MB/s eta 0:05:45
#    ---------- ----------------------------- 0.8/2.9 GB 6.3 MB/s eta 0:05:42
#    ---------- ----------------------------- 0.8/2.9 GB 6.3 MB/s eta 0:05:41
# ...
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ---------------------------------------- 0/3 [torch]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    ------------- -------------------------- 1/3 [torchvision]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    -------------------------- ------------- 2/3 [torchaudio]
#    ---------------------------------------- 3/3 [torchaudio]
#
# Successfully installed torch-2.8.0+cu126 torchaudio-2.5.1+cu121 torchvision-0.20.1+cu121
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.8.0+cu126 requires sympy>=1.13.3, but you have sympy 1.13.1 which is incompatible.

# %%
import torch

# Check if CUDA is available
print("CUDA Available:", torch.cuda.is_available())

# Get device name if available
if torch.cuda.is_available():
    print("Device count:", torch.cuda.device_count())
    print("Current device index:", torch.cuda.current_device())
    print("Device name:", torch.cuda.get_device_name(torch.cuda.current_device()))
else:
    print("Using CPU")
# Out:
# CUDA Available: True
# Device count: 1
# Current device index: 0
# Device name: NVIDIA GeForce RTX 3060

# %%
from datasets import load_dataset

ds = load_dataset("roneneldan/TinyStories")

# %%
import tiktoken              # GPT(-2/3/4) compatible token encoding/decoding
import os                    # For filesystem operations
import numpy as np           # Numerical operations / memmap arrays
from tqdm.auto import tqdm

enc = tiktoken.get_encoding("gpt2")

# Some functions from https://github.com/karpathy/nanoGPT/blob/master/data/openwebtext/prepare.py

def process(example):
    import tiktoken
    enc = tiktoken.get_encoding("gpt2")
    ids = enc.encode(example["text"])
    return {
        "ids": ids,
        "len": len(ids)  # add this line
    }


if not os.path.exists("train.bin"):
    tokenized = ds.map(
        process,
        remove_columns=['text'],
        desc="tokenizing the splits",
        num_proc=8,
        )
    # concatenate all the ids in each dataset into one large file we can use for training
    for split, dset in tokenized.items():
        arr_len = np.sum(dset['len'], dtype=np.uint64)
        filename = f'{split}.bin'
        dtype = np.uint16 # (can do since enc.max_token_value == 50256 is < 2**16)
        arr = np.memmap(filename, dtype=dtype, mode='w+', shape=(arr_len,))
        total_batches = 1024

        idx = 0
        for batch_idx in tqdm(range(total_batches), desc=f'writing {filename}'):
            # Batch together samples for faster write
            batch = dset.shard(num_shards=total_batches, index=batch_idx, contiguous=True).with_format('numpy')
            arr_batch = np.concatenate(batch['ids'])
            # Write into mmap
            arr[idx : idx + len(arr_batch)] = arr_batch
            idx += len(arr_batch)
        arr.flush()

# %%
# Some functions from https://github.com/karpathy/nanoGPT/blob/master/train.py with slight modifications
#block size = context window
import torch

def get_batch(split):
    # We recreate np.memmap every batch to avoid a memory leak, as per
    # https://stackoverflow.com/questions/45132940/numpy-memmap-memory-usage-want-to-iterate-once/61472122#61472122
    if split == 'train':
        data = np.memmap('train.bin', dtype=np.uint16, mode='r')
    else:
        data = np.memmap('validation.bin', dtype=np.uint16, mode='r')
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([torch.from_numpy((data[i:i+block_size]).astype(np.int64)) for i in ix])
    y = torch.stack([torch.from_numpy((data[i+1:i+1+block_size]).astype(np.int64)) for i in ix])
    if device_type == 'cuda':
        # pin arrays x,y, which allows us to move them to GPU asynchronously (non_blocking=True)
        x, y = x.pin_memory().to(device, non_blocking=True), y.pin_memory().to(device, non_blocking=True)
    else:
        x, y = x.to(device), y.to(device)
    return x, y

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from dataclasses import dataclass
import numpy as np
from tqdm.auto import tqdm
from contextlib import nullcontext
import os

class LayerNorm(nn.Module):
    def __init__(self, ndim, bias):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(ndim))
        self.bias = nn.Parameter(torch.zeros(ndim)) if bias else None
    def forward(self, x):
        return F.layer_norm(x, self.weight.shape, self.weight, self.bias, 1e-5)

class CausalSelfAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd, bias=config.bias)
        self.c_proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        self.attn_dropout = nn.Dropout(config.dropout)
        self.resid_dropout = nn.Dropout(config.dropout)
        self.n_head = config.n_head
        self.n_embd = config.n_embd
        self.flash = hasattr(F, 'scaled_dot_product_attention')
        if not self.flash:
            self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                       .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size()
        q, k, v = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)

        if self.flash:
            y = F.scaled_dot_product_attention(q, k, v, attn_mask=None, dropout_p=self.attn_dropout.p if self.training else 0.0, is_causal=True)
        else:
            att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
            att = att.masked_fill(self.bias[:, :, :T, :T] == 0, float('-inf'))
            att = F.softmax(att, dim=-1)
            att = self.attn_dropout(att)
            y = att @ v

        y = y.transpose(1, 2).contiguous().view(B, T, C)
        y = self.resid_dropout(self.c_proj(y))
        return y

class MLP(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.c_fc = nn.Linear(config.n_embd, 4 * config.n_embd, bias=config.bias)
        self.gelu = nn.GELU()
        self.c_proj = nn.Linear(4 * config.n_embd, config.n_embd, bias=config.bias)
        self.dropout = nn.Dropout(config.dropout)
    def forward(self, x):
        return self.dropout(self.c_proj(self.gelu(self.c_fc(x))))

class Block(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.ln1 = LayerNorm(config.n_embd, config.bias)
        self.attn = CausalSelfAttention(config)
        self.ln2 = LayerNorm(config.n_embd, config.bias)
        self.mlp = MLP(config)
    def forward(self, x):
        x = x + self.attn(self.ln1(x))
        x = x + self.mlp(self.ln2(x))
        return x

@dataclass
class GPTConfig:
    block_size: int
    vocab_size: int
    n_layer: int
    n_head: int
    n_embd: int
    dropout: float = 0.0
    bias: bool = True

class GPT(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.transformer = nn.ModuleDict(dict(
            wte=nn.Embedding(config.vocab_size, config.n_embd),
            wpe=nn.Embedding(config.block_size, config.n_embd),
            drop=nn.Dropout(config.dropout),
            h=nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f=LayerNorm(config.n_embd, config.bias),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)
        self.transformer.wte.weight = self.lm_head.weight  # weight tying

        self.apply(self._init_weights)
        for pn, p in self.named_parameters():
            if pn.endswith('c_proj.weight'):
                nn.init.normal_(p, mean=0.0, std=0.02 / math.sqrt(2 * config.n_layer))

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        device = idx.device
        b, t = idx.size()
        assert t <= self.config.block_size
        pos = torch.arange(0, t, dtype=torch.long, device=device)

        tok_emb = self.transformer.wte(idx)
        pos_emb = self.transformer.wpe(pos)
        x = self.transformer.drop(tok_emb + pos_emb)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)

        if targets is not None:
            logits = self.lm_head(x)
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)
            return logits, loss
        else:
            logits = self.lm_head(x[:, [-1], :])
            return logits, None

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=None):
        """
        Generate tokens given a conditioning sequence.
        idx: Tensor of shape (B, T)
        """
        for _ in range(max_new_tokens):
            idx_cond = idx if idx.size(1) <= self.config.block_size else idx[:, -self.config.block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :] / temperature
            if top_k is not None:
                v, _ = torch.topk(logits, min(top_k, logits.size(-1)))
                logits[logits < v[:, [-1]]] = -float('Inf')
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %%
config = GPTConfig(
    vocab_size=50257,     # use the tokenizer's vocab size
    block_size=128,       # or whatever context size you're training with
    n_layer=6,
    n_head=6,
    n_embd=384,
    dropout=0.1,
    bias=True
)

model = GPT(config)

# %%
def estimate_loss(model):
    out = {}
    model.eval()
    with torch.inference_mode():
        for split in ['train', 'val']:
            losses = torch.zeros(eval_iters)
            for k in range(eval_iters):
                X, Y = get_batch(split)
                with ctx:
                    logits, loss = model(X, Y)
                losses[k] = loss.item()
            out[split] = losses.mean()
    model.train()
    return out

# %%
# Training Config
import torch
from contextlib import nullcontext

learning_rate = 1e-4 #more stable training, earlier 1e-4
max_iters = 20000 #increase from 25000
warmup_steps = 1000 #smoother initial train, earlier 100
min_lr = 5e-4 #lower rate, earlier 5e-4
eval_iters = 500 # increased from 100
batch_size = 32 # changed from 16, better gradient estimate
block_size = 128 #changed from 64, capture longer range dependencies

gradient_accumulation_steps = 32 # reduced from 50

device =  "cuda" if torch.cuda.is_available() else "cpu"
device_type = 'cuda' if 'cuda' in device else 'cpu' # for later use in torch.autocast
# note: float16 data type will automatically use a GradScaler

# How to use autocast https://wandb.ai/wandb_fc/tips/reports/How-To-Use-Autocast-in-PyTorch--VmlldzoyMTk4NTky
#dtype = 'bfloat16' if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else 'float16' # 'float32', 'bfloat16', or 'float16', the latter will auto implement a GradScaler
dtype = 'bfloat16' if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else 'float16' # 'float32', 'bfloat16', or 'float16', the latter will auto implement a GradScaler
ptdtype = {'float32': torch.float32, 'bfloat16': torch.bfloat16, 'float16': torch.float16}[dtype]

ctx = nullcontext() if device_type == 'cpu' else torch.amp.autocast(device_type=device_type, dtype=ptdtype)

torch.set_default_device(device)
torch.manual_seed(42)

# %%
from torch.optim.lr_scheduler import LinearLR,SequentialLR, CosineAnnealingLR

##PUT IN WEIGHT DECAY, CHANGED BETA2 to 0.95
optimizer =  torch.optim.AdamW(model.parameters(), lr=learning_rate, betas=(0.9, 0.95), weight_decay=0.1, eps=1e-9) #weight decay for regularization

scheduler_warmup = LinearLR(optimizer, total_iters = warmup_steps) #Implement linear warmup
scheduler_decay = CosineAnnealingLR(optimizer,T_max = max_iters - warmup_steps, eta_min = min_lr) #Implement lr decay
scheduler = SequentialLR(optimizer, schedulers=[scheduler_warmup, scheduler_decay], milestones=[warmup_steps]) #Switching from warmup to decay

# https://stackoverflow.com/questions/72534859/is-gradscaler-necessary-with-mixed-precision-training-with-pytorch
scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# Out:
# C:\Users\WALTON\AppData\Local\Temp\ipykernel_11228\2132813893.py:11: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))

# %%
best_val_loss = float('inf')
best_model_params_path = "best_model_params.pt"
train_loss_list, validation_loss_list = [], []

# Ensure model is on the correct device
model = model.to(device)

# In your training loop
for epoch in tqdm(range(max_iters)):
    if epoch % eval_iters == 0 and epoch != 0:
        # Ensure estimate_loss uses the correct device
        losses = estimate_loss(model)
        print(f"Epoch {epoch}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        print(f"The current learning rate: {optimizer.param_groups[0]['lr']:.5f}")
        train_loss_list += [losses['train']]
        validation_loss_list += [losses['val']]

        if losses['val'] < best_val_loss:
            best_val_loss = losses['val']
            torch.save(model.state_dict(), best_model_params_path)

    # Ensure X and y are on the correct device
    X, y = get_batch("train")
    X, y = X.to(device), y.to(device)

    with ctx:
        logits, loss = model(X, y)
        loss = loss / gradient_accumulation_steps
        scaler.scale(loss).backward()

    if ((epoch + 1) % gradient_accumulation_steps == 0) or (epoch + 1 == max_iters):
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad(set_to_none=True)
    scheduler.step()
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
# e:\ai-testing\Storytime\venv\Lib\site-packages\torch\optim\lr_scheduler.py:224: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 500: train loss 9.4512, val loss 9.4577
# The current learning rate: 0.00007
# e:\ai-testing\Storytime\venv\Lib\site-packages\torch\optim\lr_scheduler.py:240: UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Epoch 1000: train loss 8.4954, val loss 8.4992
# The current learning rate: 0.00010
# Epoch 1500: train loss 7.5563, val loss 7.5540
# The current learning rate: 0.00010
# Epoch 2000: train loss 6.7041, val loss 6.7034
# The current learning rate: 0.00010
# Epoch 2500: train loss 5.9927, val loss 5.9962
# The current learning rate: 0.00011
# Epoch 3000: train loss 5.4787, val loss 5.4762
# The current learning rate: 0.00011
# Epoch 3500: train loss 5.0565, val loss 5.0486
# The current learning rate: 0.00012
# Epoch 4000: train loss 4.7370, val loss 4.7393
# The current learning rate: 0.00012
# Epoch 4500: train loss 4.4942, val loss 4.5010
# The current learning rate: 0.00013
# Epoch 5000: train loss 4.2775, val loss 4.2772
# The current learning rate: 0.00014
# Epoch 5500: train loss 4.1174, val loss 4.1171
# The current learning rate: 0.00015
# Epoch 6000: train loss 3.9575, val loss 3.9607
# The current learning rate: 0.00016
# Epoch 6500: train loss 3.8274, val loss 3.8308
# The current learning rate: 0.00018
# Epoch 7000: train loss 3.7096, val loss 3.7126
# The current learning rate: 0.00019
# Epoch 7500: train loss 3.6061, val loss 3.6034
# The current learning rate: 0.00020
# Epoch 8000: train loss 3.5064, val loss 3.5060
# The current learning rate: 0.00022
# Epoch 8500: train loss 3.4165, val loss 3.4185
# The current learning rate: 0.00024
# Epoch 9000: train loss 3.3267, val loss 3.3304
# The current learning rate: 0.00025
# Epoch 9500: train loss 3.2605, val loss 3.2659
# The current learning rate: 0.00027
# Epoch 10000: train loss 3.1882, val loss 3.1854
# The current learning rate: 0.00028
# Epoch 10500: train loss 3.1063, val loss 3.1070
# The current learning rate: 0.00030
# Epoch 11000: train loss 3.0519, val loss 3.0514
# The current learning rate: 0.00032
# Epoch 11500: train loss 2.9946, val loss 3.0025
# The current learning rate: 0.00033
# Epoch 12000: train loss 2.9454, val loss 2.9406
# The current learning rate: 0.00035
# Epoch 12500: train loss 2.8845, val loss 2.9005
# The current learning rate: 0.00036
# Epoch 13000: train loss 2.8403, val loss 2.8408
# The current learning rate: 0.00038
# Epoch 13500: train loss 2.7894, val loss 2.7937
# The current learning rate: 0.00040
# Epoch 14000: train loss 2.7503, val loss 2.7622
# The current learning rate: 0.00041
# Epoch 14500: train loss 2.7075, val loss 2.7164
# The current learning rate: 0.00042
# Epoch 15000: train loss 2.6671, val loss 2.6699
# The current learning rate: 0.00044
# Epoch 15500: train loss 2.6318, val loss 2.6281
# The current learning rate: 0.00045
# Epoch 16000: train loss 2.6000, val loss 2.6023
# The current learning rate: 0.00046
# Epoch 16500: train loss 2.5642, val loss 2.5613
# The current learning rate: 0.00047
# Epoch 17000: train loss 2.5343, val loss 2.5316
# The current learning rate: 0.00048
# Epoch 17500: train loss 2.5017, val loss 2.5009
# The current learning rate: 0.00048
# Epoch 18000: train loss 2.4685, val loss 2.4676
# The current learning rate: 0.00049
# Epoch 18500: train loss 2.4406, val loss 2.4393
# The current learning rate: 0.00049
# Epoch 19000: train loss 2.4078, val loss 2.4088
# The current learning rate: 0.00050
# Epoch 19500: train loss 2.3963, val loss 2.3960
# The current learning rate: 0.00050

# %%
import matplotlib.pyplot as plt
train_loss_list_converted = [i.cpu().detach() for i in train_loss_list]
validation_loss_list_converted = [i.cpu().detach() for i in validation_loss_list]

plt.plot(train_loss_list_converted, 'g', label='train_loss')
plt.plot(validation_loss_list_converted, 'r', label='validation_loss')
plt.xlabel("Steps - Every 100 epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
#Load the model
model = GPT(config)
device =  "cuda" if torch.cuda.is_available() else "cpu"
best_model_params_path = "best_model_params.pt"
model.load_state_dict(torch.load(best_model_params_path, map_location=torch.device(device))) # load best model states
# Out:
# C:\Users\WALTON\AppData\Local\Temp\ipykernel_11228\1220266581.py:5: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_params_path, map_location=torch.device(device))) # load best model states
# <All keys matched successfully>

# %%
sentence = "Once upon a time there was a pumpkin."
context = (torch.tensor(enc.encode_ordinary(sentence)).unsqueeze(dim = 0))
y = model.generate(context, 200)
print(enc.decode(y.squeeze().tolist()))
# Out:
# Once upon a time there was a pumpkin. It was very impressive and the ant was ate all hot. The ant was wet and tidy in his own joy. The boy was so happy that he started to take the coal out his pocket. He let the kitten go of the house, follows him.
#
# The pig was very happy and happy. He was happy. He was a happy penny on the top of the pitch, and it was very fun. The sun was bright.
#
# The boy hopped around the lake, taking his sword and gave it back home. It was safe and shiny. Under the reef, he had learned his wisdom about jelly. And now it was fun for protecting it, and he could show it all of his friends again.Once upon a time there was a silly driver. He loved to listen to Tim. Tim and Sam would watch the big truck race. One day, until they landed, when the busuttered down, they crossed the swings too fast.
#
# Peary was sad to have

# %%
sentence = "Once upon a time, there was a king named Midas. Once he wished that he had the power to convert any object into gold."
context = (torch.tensor(enc.encode_ordinary(sentence)).unsqueeze(dim = 0))
y = model.generate(context, 200)
print(enc.decode(y.squeeze().tolist()))
# Out:
# Once upon a time, there was a king named Midas. Once he wished that he had the power to convert any object into gold.
#
# One day Strieers had an accident and one of the cow knew how to add a special ornament to imagine. Chris turtles were fancy and peace from the dragon!
#  lowered his wings. Then, Beares higher as themethod each one setting every day. He was very thankful to the goat, and then he could find that could join him.
#
# gl Chomsky was a bit disappointed, and the animals had his attractive haircut so long as a circle of a beautiful star. She was eventually found the happiest fox who had left such polesave Tony.
# The End.Sophie had gave exams to school a bad ending about the goose on her marriage.Once upon a time there was a bossy king who was for a judge. He would do much that early was spraying as the camp anymore. All the other animals were all different, but the mysterious king kept marching in a very old place for another songs.
#
# The king was confused and wanted to try and

# %%
# Load saved state_dict
model.load_state_dict(torch.load(best_model_params_path, map_location=torch.device(device))) # load best model states
model.eval()

# Get parameter counts
total_params = sum(p.numel() for p in model.parameters())
trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

print(model)  # prints architecture
print(f"Total parameters: {total_params:,}")
print(f"Trainable parameters: {trainable_params:,}")

# Inspect each layer
for name, param in model.named_parameters():
    print(f"{name:20} {list(param.size())}  Trainable={param.requires_grad}")
# Out:
# GPT(
#   (transformer): ModuleDict(
#     (wte): Embedding(50257, 384)
#     (wpe): Embedding(128, 384)
#     (drop): Dropout(p=0.1, inplace=False)
#     (h): ModuleList(
#       (0-5): 6 x Block(
#         (ln1): LayerNorm()
#         (attn): CausalSelfAttention(
#           (c_attn): Linear(in_features=384, out_features=1152, bias=True)
#           (c_proj): Linear(in_features=384, out_features=384, bias=True)
#           (attn_dropout): Dropout(p=0.1, inplace=False)
#           (resid_dropout): Dropout(p=0.1, inplace=False)
#         )
#         (ln2): LayerNorm()
#         (mlp): MLP(
#           (c_fc): Linear(in_features=384, out_features=1536, bias=True)
#           (gelu): GELU(approximate='none')
#           (c_proj): Linear(in_features=1536, out_features=384, bias=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#     (ln_f): LayerNorm()
#   )
#   (lm_head): Linear(in_features=384, out_features=50257, bias=False)
# )
# Total parameters: 29,995,392
# Trainable parameters: 29,995,392
# transformer.wte.weight [50257, 384]  Trainable=True
# transformer.wpe.weight [128, 384]  Trainable=True
# transformer.h.0.ln1.weight [384]  Trainable=True
# transformer.h.0.ln1.bias [384]  Trainable=True
# transformer.h.0.attn.c_attn.weight [1152, 384]  Trainable=True
# transformer.h.0.attn.c_attn.bias [1152]  Trainable=True
# transformer.h.0.attn.c_proj.weight [384, 384]  Trainable=True
# transformer.h.0.attn.c_proj.bias [384]  Trainable=True
# transformer.h.0.ln2.weight [384]  Trainable=True
# transformer.h.0.ln2.bias [384]  Trainable=True
# transformer.h.0.mlp.c_fc.weight [1536, 384]  Trainable=True
# transformer.h.0.mlp.c_fc.bias [1536]  Trainable=True
# transformer.h.0.mlp.c_proj.weight [384, 1536]  Trainable=True
# transformer.h.0.mlp.c_proj.bias [384]  Trainable=True
# transformer.h.1.ln1.weight [384]  Trainable=True
# transformer.h.1.ln1.bias [384]  Trainable=True
# transformer.h.1.attn.c_attn.weight [1152, 384]  Trainable=True
# transformer.h.1.attn.c_attn.bias [1152]  Trainable=True
# transformer.h.1.attn.c_proj.weight [384, 384]  Trainable=True
# transformer.h.1.attn.c_proj.bias [384]  Trainable=True
# transformer.h.1.ln2.weight [384]  Trainable=True
# transformer.h.1.ln2.bias [384]  Trainable=True
# transformer.h.1.mlp.c_fc.weight [1536, 384]  Trainable=True
# transformer.h.1.mlp.c_fc.bias [1536]  Trainable=True
# transformer.h.1.mlp.c_proj.weight [384, 1536]  Trainable=True
# transformer.h.1.mlp.c_proj.bias [384]  Trainable=True
# transformer.h.2.ln1.weight [384]  Trainable=True
# transformer.h.2.ln1.bias [384]  Trainable=True
# transformer.h.2.attn.c_attn.weight [1152, 384]  Trainable=True
# transformer.h.2.attn.c_attn.bias [1152]  Trainable=True
# transformer.h.2.attn.c_proj.weight [384, 384]  Trainable=True
# transformer.h.2.attn.c_proj.bias [384]  Trainable=True
# transformer.h.2.ln2.weight [384]  Trainable=True
# transformer.h.2.ln2.bias [384]  Trainable=True
# transformer.h.2.mlp.c_fc.weight [1536, 384]  Trainable=True
# transformer.h.2.mlp.c_fc.bias [1536]  Trainable=True
# transformer.h.2.mlp.c_proj.weight [384, 1536]  Trainable=True
# transformer.h.2.mlp.c_proj.bias [384]  Trainable=True
# transformer.h.3.ln1.weight [384]  Trainable=True
# transformer.h.3.ln1.bias [384]  Trainable=True
# transformer.h.3.attn.c_attn.weight [1152, 384]  Trainable=True
# transformer.h.3.attn.c_attn.bias [1152]  Trainable=True
# transformer.h.3.attn.c_proj.weight [384, 384]  Trainable=True
# transformer.h.3.attn.c_proj.bias [384]  Trainable=True
# transformer.h.3.ln2.weight [384]  Trainable=True
# transformer.h.3.ln2.bias [384]  Trainable=True
# transformer.h.3.mlp.c_fc.weight [1536, 384]  Trainable=True
# transformer.h.3.mlp.c_fc.bias [1536]  Trainable=True
# transformer.h.3.mlp.c_proj.weight [384, 1536]  Trainable=True
# transformer.h.3.mlp.c_proj.bias [384]  Trainable=True
# transformer.h.4.ln1.weight [384]  Trainable=True
# transformer.h.4.ln1.bias [384]  Trainable=True
# transformer.h.4.attn.c_attn.weight [1152, 384]  Trainable=True
# transformer.h.4.attn.c_attn.bias [1152]  Trainable=True
# transformer.h.4.attn.c_proj.weight [384, 384]  Trainable=True
# transformer.h.4.attn.c_proj.bias [384]  Trainable=True
# transformer.h.4.ln2.weight [384]  Trainable=True
# transformer.h.4.ln2.bias [384]  Trainable=True
# transformer.h.4.mlp.c_fc.weight [1536, 384]  Trainable=True
# transformer.h.4.mlp.c_fc.bias [1536]  Trainable=True
# transformer.h.4.mlp.c_proj.weight [384, 1536]  Trainable=True
# transformer.h.4.mlp.c_proj.bias [384]  Trainable=True
# transformer.h.5.ln1.weight [384]  Trainable=True
# transformer.h.5.ln1.bias [384]  Trainable=True
# transformer.h.5.attn.c_attn.weight [1152, 384]  Trainable=True
# transformer.h.5.attn.c_attn.bias [1152]  Trainable=True
# transformer.h.5.attn.c_proj.weight [384, 384]  Trainable=True
# transformer.h.5.attn.c_proj.bias [384]  Trainable=True
# transformer.h.5.ln2.weight [384]  Trainable=True
# transformer.h.5.ln2.bias [384]  Trainable=True
# transformer.h.5.mlp.c_fc.weight [1536, 384]  Trainable=True
# transformer.h.5.mlp.c_fc.bias [1536]  Trainable=True
# transformer.h.5.mlp.c_proj.weight [384, 1536]  Trainable=True
# transformer.h.5.mlp.c_proj.bias [384]  Trainable=True
# transformer.ln_f.weight [384]  Trainable=True
# transformer.ln_f.bias [384]  Trainable=True
# C:\Users\WALTON\AppData\Local\Temp\ipykernel_11228\3099427368.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(best_model_params_path, map_location=torch.device(device))) # load best model states

# %%
import torch

checkpoint = torch.load("best_model_params.pt", map_location="cpu")
print(checkpoint.keys())
# Out:
# odict_keys(['transformer.wte.weight', 'transformer.wpe.weight', 'transformer.h.0.ln1.weight', 'transformer.h.0.ln1.bias', 'transformer.h.0.attn.c_attn.weight', 'transformer.h.0.attn.c_attn.bias', 'transformer.h.0.attn.c_proj.weight', 'transformer.h.0.attn.c_proj.bias', 'transformer.h.0.ln2.weight', 'transformer.h.0.ln2.bias', 'transformer.h.0.mlp.c_fc.weight', 'transformer.h.0.mlp.c_fc.bias', 'transformer.h.0.mlp.c_proj.weight', 'transformer.h.0.mlp.c_proj.bias', 'transformer.h.1.ln1.weight', 'transformer.h.1.ln1.bias', 'transformer.h.1.attn.c_attn.weight', 'transformer.h.1.attn.c_attn.bias', 'transformer.h.1.attn.c_proj.weight', 'transformer.h.1.attn.c_proj.bias', 'transformer.h.1.ln2.weight', 'transformer.h.1.ln2.bias', 'transformer.h.1.mlp.c_fc.weight', 'transformer.h.1.mlp.c_fc.bias', 'transformer.h.1.mlp.c_proj.weight', 'transformer.h.1.mlp.c_proj.bias', 'transformer.h.2.ln1.weight', 'transformer.h.2.ln1.bias', 'transformer.h.2.attn.c_attn.weight', 'transformer.h.2.attn.c_attn.bias', 'transformer.h.2.attn.c_proj.weight', 'transformer.h.2.attn.c_proj.bias', 'transformer.h.2.ln2.weight', 'transformer.h.2.ln2.bias', 'transformer.h.2.mlp.c_fc.weight', 'transformer.h.2.mlp.c_fc.bias', 'transformer.h.2.mlp.c_proj.weight', 'transformer.h.2.mlp.c_proj.bias', 'transformer.h.3.ln1.weight', 'transformer.h.3.ln1.bias', 'transformer.h.3.attn.c_attn.weight', 'transformer.h.3.attn.c_attn.bias', 'transformer.h.3.attn.c_proj.weight', 'transformer.h.3.attn.c_proj.bias', 'transformer.h.3.ln2.weight', 'transformer.h.3.ln2.bias', 'transformer.h.3.mlp.c_fc.weight', 'transformer.h.3.mlp.c_fc.bias', 'transformer.h.3.mlp.c_proj.weight', 'transformer.h.3.mlp.c_proj.bias', 'transformer.h.4.ln1.weight', 'transformer.h.4.ln1.bias', 'transformer.h.4.attn.c_attn.weight', 'transformer.h.4.attn.c_attn.bias', 'transformer.h.4.attn.c_proj.weight', 'transformer.h.4.attn.c_proj.bias', 'transformer.h.4.ln2.weight', 'transformer.h.4.ln2.bias', 'transformer.h.4.mlp.c_fc.weight', 'transformer.h.4.mlp.c_fc.bias', 'transformer.h.4.mlp.c_proj.weight', 'transformer.h.4.mlp.c_proj.bias', 'transformer.h.5.ln1.weight', 'transformer.h.5.ln1.bias', 'transformer.h.5.attn.c_attn.weight', 'transformer.h.5.attn.c_attn.bias', 'transformer.h.5.attn.c_proj.weight', 'transformer.h.5.attn.c_proj.bias', 'transformer.h.5.ln2.weight', 'transformer.h.5.ln2.bias', 'transformer.h.5.mlp.c_fc.weight', 'transformer.h.5.mlp.c_fc.bias', 'transformer.h.5.mlp.c_proj.weight', 'transformer.h.5.mlp.c_proj.bias', 'transformer.ln_f.weight', 'transformer.ln_f.bias', 'lm_head.weight'])
# C:\Users\WALTON\AppData\Local\Temp\ipykernel_11228\3563447338.py:3: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load("best_model_params.pt", map_location="cpu")
